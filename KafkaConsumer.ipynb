# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'KafkaStockMarket',
     bootstrap_servers=[''], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')),
    auto_offset_reset='latest'
)

# %%
for c in consumer:
    print(c.value)

# %%
print("Muhammad Shaheer Jamal")

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    # with s3.open("s3://kafkastockmarketprojecthome/stock_market_{}.json".format(count), 'w') as file:
    with s3.open(f"s3://kafkastockmarketprojecthome/stock_market_{count}.json", 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 for count, i in enumerate(consumer):
#       2     # with s3.open("s3://kafkastockmarketprojecthome/stock_market_{}.json".format(count), 'w') as file:
# ----> 3     with s3.open(f"s3://kafkastockmarketprojecthome/stock_market_{count}.json", 'w') as file:
#       4         json.dump(i.value, file)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\spec.py:2217, in AbstractBufferedFile.close(self)
#    2215 else:
#    2216     if not self.forced:
# -> 2217         self.flush(force=True)
#    2219     if self.fs is not None:
#    2220         self.fs.invalidate_cache(self.path)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\spec.py:2080, in AbstractBufferedFile.flush(self, force)
#    2077         self.closed = True
#    2078         raise
# ...

# %%
for count, i in enumerate(consumer):
    print(count)
    print(i.value)
